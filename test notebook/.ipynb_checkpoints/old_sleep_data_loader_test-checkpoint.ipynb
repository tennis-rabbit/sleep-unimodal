# %%
# dataset.py
import numpy as np
import pandas as pd
from pathlib import Path
from functools import lru_cache
from typing import Sequence, Optional, Tuple, Union, List, Dict

import torch
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split


class SleepEpochDataset(Dataset):
    """
    A PyTorch Dataset that delivers 30-second sleep epochs together
    with optional patient-level labels.

    Parameters
    ----------
    epoch_df : pd.DataFrame
        Epoch-level table. Must contain at least:
            - "nsrrid"       : patient ID
            - "epoch_id"     : 1-based epoch index
            - "path_head"    : prefix to the signal file on disk
    patient_df : pd.DataFrame | str | Path
        Patient-level table or the CSV file path; must contain
        "nsrrid" plus any downstream label columns.
    split : {"train", "val", "test"}
        Which split to use. Partitioning is done by patient ID
        so all epochs from the same patient stay in the same split.
    target_cols : str | Sequence[str] | None
        The patient-level label column(s) to return.  None = no labels
        (e.g. for self-supervised pre-training).
    test_size, val_size : float
        Fractions for patient-level train/val/test split.
    random_state : int
        Seed for deterministic splitting.
    sample_rate : int
        Sampling rate (Hz) of the pre-processed signal.
    cache_size : int
        LRU cache size for whole-night signals to avoid reloading.
    transform : callable | None
        Optional transform / augmentation applied to the epoch tensor.
    split_ids : dict | None
        Pre-defined {"train": [...], "val": [...], "test": [...]} lists.
        If supplied, overrides the random split.
    """

    def __init__(
        self,
        epoch_df: pd.DataFrame,
        patient_df: Union[pd.DataFrame, str, Path],
        split: str = "train",
        *,
        target_cols: Optional[Union[str, Sequence[str]]] = None,
        train_edf_cols = None,
        test_size: float = 0.15,
        val_size: float = 0.15,
        random_state: int = 1337,
        sample_rate: int = 128,
        cache_size: int = 8,
        transform=None,
        split_ids: Optional[Dict[str, Sequence[str]]] = None,
    ):
        assert split in {"train", "val", "test"}
        self.transform = transform
        self.sample_rate = sample_rate
        self.target_cols = (
            [target_cols] if isinstance(target_cols, str) else target_cols
        )

        # ───── patient-level DataFrame ─────
        if isinstance(patient_df, (str, Path)):
            patient_df = pd.read_csv(patient_df)
        self.patient_df = patient_df.set_index("nsrrid")

        # ───── create / use patient splits ─────
        if split_ids is None:
            ids = self.patient_df.index.unique().tolist()

            train_ids, temp_ids = train_test_split(
                ids,
                test_size=(val_size + test_size),
                random_state=random_state,
            )
            rel_val = val_size / (val_size + test_size)
            val_ids, test_ids = train_test_split(
                temp_ids,
                test_size=1.0 - rel_val,
                random_state=random_state,
            )
            split_ids = {
                "train": train_ids,
                "val": val_ids,
                "test": test_ids,
            }

        self.split_ids = split_ids
        self.epoch_df = (
            epoch_df[epoch_df["nsrrid"].isin(split_ids[split])]
            .reset_index(drop=True)
        )

        # ───── LRU cache for whole-night signals ─────
        self._load_patient_array = lru_cache(maxsize=cache_size)(
            self._load_patient_array
        )
        self.train_edf_cols = train_edf_cols

    # ───────── Dataset API ─────────

    def __len__(self) -> int:
        return len(self.epoch_df)

    def __getitem__(self, idx: int):
        row = self.epoch_df.iloc[idx]
        nsrrid = row["nsrrid"]
        epoch_id = int(row["epoch_id"])

        # 1) load full-night signal and slice to this epoch
        t10 = time.perf_counter() 
        
        dfs = []
        for col_name in self.train_edf_cols:
            temp_sig = self._load_patient_array(nsrrid, row["path_head"], col_name = col_name)
            dfs.append(temp_sig)
        full_sig = pd.concat(dfs, axis = 1)
        t11 = time.perf_counter() 
        print(f"time of get channel data {idx} row: {t11 - t10:.3f} s")
        
        t20 = time.perf_counter() 
        start_sec = (epoch_id - 1) * 30
        end_sec = epoch_id * 30
        epoch_sig = full_sig.loc[start_sec: end_sec]
        epoch_sig = epoch_sig.iloc[:-1] # remove the last point
        
        x = torch.tensor(epoch_sig.values, dtype=torch.float32)
        
        # 1.5) can add other transformation here
        if self.transform:
            x = self.transform(x)
        t21 = time.perf_counter() 
        print(f"time of truncate and transform data {idx} row: {t21 - t20:.3f} s")
        
        # 2) add patient-level label(s) if requested
        if self.target_cols:
            y = torch.tensor(
                self.patient_df.loc[nsrrid, self.target_cols].values.astype(float),
                dtype=torch.float32,
            )
            return x, y
        else:
            return x


    def _build_signal_path(self, path_head: str, col_name = 'ECG') -> Path:
        """
        Convert path_head to the actual signal file path.
        Default: '<path_head>_data.npz' with key 'signal'.
        Adjust if your filenames / keys differ.
        """
        return Path(path_head + f"_{col_name}.npz")

    def _load_patient_array(self, nsrrid: str, path_head: str, col_name = 'ECG') -> np.ndarray:
        """
        Load the full-night signal into a NumPy array.
        If you have multiple channels, return shape (C, T).
        """
        fp = self._build_signal_path(path_head, col_name)
        if not fp.is_file():
            raise FileNotFoundError(f"Signal file missing: {fp}")
        with np.load(fp, allow_pickle=False) as npz:
            data = npz['values']
            index = npz['index']

            df_stg = pd.DataFrame(
                data,
                columns=[col_name]
            )
            df_stg.insert(0, "sec", index)
            
            sig = df_stg.set_index("sec")           
            
        return sig.astype(np.float32)

# %%
import pandas as pd
from torch.utils.data import DataLoader

epoch_df = pd.read_csv('/scratch/besp/shared_data/df_epoch_level_all.csv')
patient_df = pd.read_csv('/u/ztshuai/ondemand/postprocess/example_patient_level_master.csv')
TRAIN_EDF_COLS = [ECG]
train_set = SleepEpochDataset(
    epoch_df, patient_df, split="train",
    train_edf_cols = TRAIN_EDF_COLS,
    target_cols=["nsrr_bmi"],     # or None
    sample_rate=128,
)

# %%
train_loader = DataLoader(
    train_set,
    batch_size=128,
    shuffle=True,
    num_workers=4,
    pin_memory=True,
)


import time 
it = iter(train_loader) 
t0 = time.perf_counter() 
batch = next(it)
t1 = time.perf_counter() 
print(f"1st-batch load: {t1 - t0:.3f} s")
# Out:
# time of get channel data 3055559 row: 0.799 s
# time of truncate and ransform data 3055559 row: 0.005 s
# time of get channel data 1468497 row: 0.879 s
# time of get channel data 727750 row: 0.926 s
# time of truncate and ransform data 1468497 row: 0.009 stime of truncate and ransform data 727750 row: 0.005 s
#
# time of get channel data 522362 row: 0.999 s
# time of truncate and ransform data 522362 row: 0.005 s
# time of get channel data 1451926 row: 0.139 s
# time of truncate and ransform data 1451926 row: 0.003 s
# time of get channel data 908522 row: 0.333 s
# time of truncate and ransform data 908522 row: 0.005 s
# time of get channel data 1441013 row: 0.490 s
# time of truncate and ransform data 1441013 row: 0.004 s
# time of get channel data 3963005 row: 0.512 s
# time of truncate and ransform data 3963005 row: 0.003 s
# time of get channel data 2949548 row: 0.404 s
# time of get channel data 1146600 row: 0.306 s
# time of truncate and ransform data 1146600 row: 0.003 s
# time of truncate and ransform data 2949548 row: 0.005 s
# time of get channel data 2222298 row: 0.344 s
# time of truncate and ransform data 2222298 row: 0.004 s
# time of get channel data 1411694 row: 0.481 s
# time of truncate and ransform data 1411694 row: 0.004 stime of get channel data 4599198 row: 0.623 s
#
# time of truncate and ransform data 4599198 row: 0.003 s
# time of get channel data 3434125 row: 0.459 s
# time of truncate and ransform data 3434125 row: 0.003 s
# time of get channel data 754299 row: 0.201 s
# time of truncate and ransform data 754299 row: 0.003 s
# time of get channel data 1074144 row: 0.277 s
# time of truncate and ransform data 1074144 row: 0.004 s
# time of get channel data 1307517 row: 0.428 s
# time of truncate and ransform data 1307517 row: 0.004 s
# time of get channel data 4641410 row: 0.416 s
# time of truncate and ransform data 4641410 row: 0.005 stime of get channel data 4463428 row: 0.626 s
# time of truncate and ransform data 4463428 row: 0.004 s
#
# time of get channel data 2617984 row: 0.413 s
# time of truncate and ransform data 2617984 row: 0.005 s
# time of get channel data 1677255 row: 0.306 s
# time of truncate and ransform data 1677255 row: 0.004 s
# time of get channel data 4270917 row: 0.483 s
# time of truncate and ransform data 4270917 row: 0.005 s
# time of get channel data 323490 row: 0.332 s
# time of truncate and ransform data 323490 row: 0.005 s
# time of get channel data 3781855 row: 0.841 s
# time of truncate and ransform data 3781855 row: 0.005 s
# time of get channel data 2542118 row: 0.447 s
# time of truncate and ransform data 2542118 row: 0.005 s
# time of get channel data 3426251 row: 0.323 s
# time of truncate and ransform data 3426251 row: 0.005 s
# time of get channel data 485134 row: 0.538 s
# time of truncate and ransform data 485134 row: 0.004 stime of get channel data 557598 row: 0.467 s
#
# time of truncate and ransform data 557598 row: 0.005 s
# time of get channel data 823920 row: 0.348 s
# time of get channel data 328426 row: 0.396 s
# time of truncate and ransform data 823920 row: 0.005 s
# time of truncate and ransform data 328426 row: 0.004 s
# time of get channel data 650999 row: 0.158 s
# time of truncate and ransform data 650999 row: 0.004 s
# time of get channel data 2972673 row: 0.411 s
# time of truncate and ransform data 2972673 row: 0.004 s
# time of get channel data 2661973 row: 0.390 s
# time of truncate and ransform data 2661973 row: 0.005 s
# time of get channel data 4141885 row: 0.620 s
# time of truncate and ransform data 4141885 row: 0.005 s
# time of get channel data 1470311 row: 0.342 s
# time of truncate and ransform data 1470311 row: 0.004 s
# time of get channel data 4550328 row: 0.898 s
# time of truncate and ransform data 4550328 row: 0.005 s
# time of get channel data 4398190 row: 0.440 s
# time of truncate and ransform data 4398190 row: 0.007 s
# time of get channel data 3340400 row: 0.378 s
# time of truncate and ransform data 3340400 row: 0.004 s
# time of get channel data 2885162 row: 0.315 s
# time of truncate and ransform data 2885162 row: 0.006 s
# time of get channel data 632689 row: 0.478 s
# time of truncate and ransform data 632689 row: 0.005 s
# time of get channel data 988415 row: 0.292 s
# time of truncate and ransform data 988415 row: 0.004 s
# time of get channel data 3580006 row: 0.340 s
# time of get channel data 3693291 row: 0.707 stime of truncate and ransform data 3580006 row: 0.007 s
#
# time of truncate and ransform data 3693291 row: 0.004 s
# time of get channel data 2448246 row: 0.537 s
# time of truncate and ransform data 2448246 row: 0.005 s
# time of get channel data 2143038 row: 0.295 s
# time of truncate and ransform data 2143038 row: 0.005 s
# time of get channel data 2439002 row: 0.485 s
# time of truncate and ransform data 2439002 row: 0.006 s
# time of get channel data 2273159 row: 0.385 s
# time of truncate and ransform data 2273159 row: 0.006 s
# time of get channel data 3912536 row: 0.992 s
# time of truncate and ransform data 3912536 row: 0.007 s
# time of get channel data 1402046 row: 0.288 s
# time of truncate and ransform data 1402046 row: 0.005 s
# time of get channel data 5244716 row: 0.584 s
# time of get channel data 3120563 row: 0.163 stime of truncate and ransform data 5244716 row: 0.004 s
#
# time of truncate and ransform data 3120563 row: 0.005 s
# time of get channel data 1806728 row: 0.386 s
# time of truncate and ransform data 1806728 row: 0.006 s
# time of get channel data 2205591 row: 0.451 s
# time of truncate and ransform data 2205591 row: 0.006 s
# time of get channel data 1453501 row: 0.452 s
# time of truncate and ransform data 1453501 row: 0.004 s
# time of get channel data 5142965 row: 0.716 s
# time of truncate and ransform data 5142965 row: 0.007 s
# time of get channel data 2145794 row: 0.288 s
# time of truncate and ransform data 2145794 row: 0.005 s
# time of get channel data 5191292 row: 0.373 s
# time of truncate and ransform data 5191292 row: 0.005 s
# time of get channel data 2180166 row: 0.332 s
# time of truncate and ransform data 2180166 row: 0.006 s
# time of get channel data 5079990 row: 0.702 s
# time of truncate and ransform data 5079990 row: 0.006 s
# time of get channel data 1355747 row: 0.309 s
# time of truncate and ransform data 1355747 row: 0.004 s
# time of get channel data 4465081 row: 0.448 s
# time of truncate and ransform data 4465081 row: 0.004 s
# time of get channel data 1871726 row: 0.504 s
# time of truncate and ransform data 1871726 row: 0.006 s
# time of get channel data 347166 row: 0.483 s
# time of truncate and ransform data 347166 row: 0.005 s
# time of get channel data 5097547 row: 0.532 s
# time of truncate and ransform data 5097547 row: 0.004 s
# time of get channel data 4154988 row: 0.954 s
# time of truncate and ransform data 4154988 row: 0.006 s
# time of get channel data 3441549 row: 0.367 s
# time of truncate and ransform data 3441549 row: 0.004 s
# time of get channel data 2600236 row: 0.518 s
# time of truncate and ransform data 2600236 row: 0.006 s
# time of get channel data 4277063 row: 0.516 s
# time of truncate and ransform data 4277063 row: 0.004 s
# time of get channel data 454363 row: 0.432 s
# time of truncate and ransform data 454363 row: 0.005 s
# time of get channel data 3381858 row: 0.353 s
# time of truncate and ransform data 3381858 row: 0.005 s
# time of get channel data 5097272 row: 0.597 s
# time of truncate and ransform data 5097272 row: 0.005 s
# time of get channel data 1064394 row: 0.283 s
# time of truncate and ransform data 1064394 row: 0.006 s
# time of get channel data 13283 row: 0.322 s
# time of truncate and ransform data 13283 row: 0.004 s
# time of get channel data 385793 row: 0.511 s
# time of truncate and ransform data 385793 row: 0.004 s
# time of get channel data 641887 row: 0.392 s
# time of truncate and ransform data 641887 row: 0.004 s
# time of get channel data 3019483 row: 0.251 s
# time of truncate and ransform data 3019483 row: 0.004 s
# time of get channel data 4649918 row: 0.658 s
# time of truncate and ransform data 4649918 row: 0.006 s
# time of get channel data 3114838 row: 0.343 s
# time of truncate and ransform data 3114838 row: 0.004 s
# time of get channel data 4740664 row: 0.798 s
# time of truncate and ransform data 4740664 row: 0.005 s
# time of get channel data 1471189 row: 0.212 s
# time of get channel data 12217 row: 0.299 s
# time of truncate and ransform data 1471189 row: 0.004 s
# time of truncate and ransform data 12217 row: 0.004 s
# time of get channel data 5022665 row: 0.901 s
# time of truncate and ransform data 5022665 row: 0.005 s
# time of get channel data 2450091 row: 0.488 s
# time of get channel data 1746251 row: 0.331 stime of truncate and ransform data 2450091 row: 0.004 s
# time of truncate and ransform data 1746251 row: 0.008 s
#
# time of get channel data 4894523 row: 0.592 s
# time of truncate and ransform data 4894523 row: 0.005 s
# time of get channel data 1951652 row: 0.369 s
# time of get channel data 2893760 row: 0.407 stime of truncate and ransform data 1951652 row: 0.004 s
#
# time of truncate and ransform data 2893760 row: 0.005 s
# time of get channel data 1233085 row: 0.487 s
# time of truncate and ransform data 1233085 row: 0.004 s
# time of get channel data 3365557 row: 0.301 s
# time of truncate and ransform data 3365557 row: 0.004 s
# time of get channel data 4339899 row: 0.595 s
# time of truncate and ransform data 4339899 row: 0.007 s
# time of get channel data 5014466 row: 0.717 stime of get channel data 4486523 row: 0.720 s
# time of truncate and ransform data 5014466 row: 0.005 s
#
# time of truncate and ransform data 4486523 row: 0.005 s
# time of get channel data 2426726 row: 0.207 s
# time of truncate and ransform data 2426726 row: 0.005 s
# time of get channel data 4846863 row: 0.756 s
# time of truncate and ransform data 4846863 row: 0.006 s
# time of get channel data 2295555 row: 0.331 s
# time of truncate and ransform data 2295555 row: 0.004 s
# time of get channel data 1526497 row: 0.346 s
# time of truncate and ransform data 1526497 row: 0.006 s
# time of get channel data 2343905 row: 0.431 s
# time of truncate and ransform data 2343905 row: 0.006 s
# time of get channel data 3862085 row: 0.610 s
# time of get channel data 225260 row: 0.199 s
# time of truncate and ransform data 3862085 row: 0.004 s
# time of truncate and ransform data 225260 row: 0.006 s
# time of get channel data 1558111 row: 0.213 s
# time of truncate and ransform data 1558111 row: 0.006 s
# time of get channel data 1487693 row: 0.384 s
# time of truncate and ransform data 1487693 row: 0.004 s
# time of get channel data 4604973 row: 0.798 stime of get channel data 2236255 row: 0.587 s
# time of truncate and ransform data 2236255 row: 0.004 s
#
# time of truncate and ransform data 4604973 row: 0.007 s
# time of get channel data 2571043 row: 0.455 s
# time of get channel data 1471084 row: 0.129 s
# time of truncate and ransform data 2571043 row: 0.006 stime of truncate and ransform data 1471084 row: 0.004 s
#
# time of get channel data 976749 row: 0.279 s
# time of truncate and ransform data 976749 row: 0.006 s
# time of get channel data 4362100 row: 0.683 s
# time of get channel data 1905978 row: 0.356 s
# time of truncate and ransform data 1905978 row: 0.005 s
# time of truncate and ransform data 4362100 row: 0.007 s
# time of get channel data 2850801 row: 0.536 s
# time of truncate and ransform data 2850801 row: 0.004 s
# time of get channel data 1478210 row: 0.301 s
# time of truncate and ransform data 1478210 row: 0.005 s
# time of get channel data 1555409 row: 0.557 s
# time of truncate and ransform data 1555409 row: 0.005 stime of get channel data 728524 row: 0.426 s
#
# time of truncate and ransform data 728524 row: 0.006 stime of get channel data 150986 row: 0.287 s
# time of truncate and ransform data 150986 row: 0.004 s
#
# time of get channel data 1355704 row: 0.214 s
# time of truncate and ransform data 1355704 row: 0.006 s
# time of get channel data 2273555 row: 0.142 s
# time of truncate and ransform data 2273555 row: 0.004 s
# time of get channel data 2482514 row: 0.267 s
# time of truncate and ransform data 2482514 row: 0.006 s
# time of get channel data 2862337 row: 0.397 s
# time of truncate and ransform data 2862337 row: 0.006 s
# time of get channel data 5136088 row: 0.542 s
# time of truncate and ransform data 5136088 row: 0.004 s
# time of get channel data 3654188 row: 0.622 s
# time of truncate and ransform data 3654188 row: 0.006 s
# time of get channel data 924534 row: 0.367 s
# time of truncate and ransform data 924534 row: 0.006 s
# time of get channel data 2488224 row: 0.403 s
# time of truncate and ransform data 2488224 row: 0.006 s
# time of get channel data 803520 row: 0.298 s
# time of truncate and ransform data 803520 row: 0.005 s
# time of get channel data 3193313 row: 0.310 stime of get channel data 2142307 row: 0.124 s
# time of truncate and ransform data 2142307 row: 0.004 s
#
# time of truncate and ransform data 3193313 row: 0.005 s
# time of get channel data 3255720 row: 0.338 s
# time of truncate and ransform data 3255720 row: 0.005 s
# time of get channel data 4409502 row: 0.704 s
# time of truncate and ransform data 4409502 row: 0.007 s
# time of get channel data 880407 row: 0.325 s
# time of truncate and ransform data 880407 row: 0.004 stime of get channel data 4274935 row: 1.054 s
#
# time of get channel data 3815888 row: 0.766 stime of truncate and ransform data 4274935 row: 0.006 s
#
# time of truncate and ransform data 3815888 row: 0.005 s
# time of get channel data 3201426 row: 0.456 s
# time of truncate and ransform data 3201426 row: 0.004 s
# time of get channel data 2253895 row: 0.331 s
# time of truncate and ransform data 2253895 row: 0.004 s
# time of get channel data 2581888 row: 0.340 s
# time of truncate and ransform data 2581888 row: 0.008 s
# time of get channel data 4558388 row: 0.658 stime of get channel data 4804503 row: 0.728 s
#
# time of truncate and ransform data 4804503 row: 0.006 s
# time of truncate and ransform data 4558388 row: 0.005 s
# time of get channel data 2370370 row: 0.311 s
# time of truncate and ransform data 2370370 row: 0.006 s
# time of get channel data 1624964 row: 0.335 s
# time of truncate and ransform data 1624964 row: 0.005 stime of get channel data 4562337 row: 0.783 s
#
# time of truncate and ransform data 4562337 row: 0.005 s
# time of get channel data 2984669 row: 0.514 s
# time of truncate and ransform data 2984669 row: 0.006 s
# time of get channel data 588315 row: 0.494 s
# time of truncate and ransform data 588315 row: 0.006 s
# time of get channel data 1019126 row: 0.349 stime of get channel data 3283518 row: 0.383 s
# time of truncate and ransform data 1019126 row: 0.004 s
#
# time of truncate and ransform data 3283518 row: 0.006 s
# time of get channel data 3386194 row: 0.294 s
# time of truncate and ransform data 3386194 row: 0.004 s
# time of get channel data 1386611 row: 0.265 s
# time of truncate and ransform data 1386611 row: 0.006 s
# time of get channel data 3557727 row: 0.745 s
# time of get channel data 5104029 row: 0.620 s
# time of truncate and ransform data 3557727 row: 0.005 s
# time of truncate and ransform data 5104029 row: 0.005 s
# time of get channel data 2229640 row: 0.345 s
# time of truncate and ransform data 2229640 row: 0.006 s
# time of get channel data 4923332 row: 0.719 s
# time of truncate and ransform data 4923332 row: 0.007 s
# time of get channel data 3409303 row: 0.348 s
# time of truncate and ransform data 3409303 row: 0.004 s
# time of get channel data 2805836 row: 0.347 s
# time of truncate and ransform data 2805836 row: 0.004 s
# time of get channel data 2000835 row: 0.367 s
# time of truncate and ransform data 2000835 row: 0.006 s
# time of get channel data 3027676 row: 0.498 s
# time of truncate and ransform data 3027676 row: 0.005 s
# time of get channel data 3877449 row: 0.244 s
# time of truncate and ransform data 3877449 row: 0.005 s
# time of get channel data 1779227 row: 0.327 s
# time of truncate and ransform data 1779227 row: 0.006 s
# time of get channel data 1208259 row: 0.260 s
# time of truncate and ransform data 1208259 row: 0.004 s
# time of get channel data 3880879 row: 0.650 s
# time of truncate and ransform data 3880879 row: 0.007 s
# time of get channel data 2950557 row: 0.674 stime of get channel data 1783921 row: 0.394 s
#
# time of truncate and ransform data 1783921 row: 0.005 s
# time of truncate and ransform data 2950557 row: 0.006 s
# time of get channel data 2010615 row: 0.253 s
# time of truncate and ransform data 2010615 row: 0.005 s
# time of get channel data 3427750 row: 0.402 s
# time of truncate and ransform data 3427750 row: 0.004 s
# time of get channel data 251184 row: 0.382 s
# time of truncate and ransform data 251184 row: 0.006 s
# time of get channel data 4865283 row: 0.528 s
# time of truncate and ransform data 4865283 row: 0.005 s
# time of get channel data 3408302 row: 0.278 stime of get channel data 3826223 row: 0.848 s
# time of truncate and ransform data 3408302 row: 0.006 s
#
# time of truncate and ransform data 3826223 row: 0.005 s
# time of get channel data 451471 row: 0.491 s
# time of truncate and ransform data 451471 row: 0.006 s
# time of get channel data 13388 row: 0.133 s
# time of truncate and ransform data 13388 row: 0.005 s
# time of get channel data 1380348 row: 0.187 s
# time of truncate and ransform data 1380348 row: 0.006 s
# time of get channel data 4475546 row: 0.763 s
# time of truncate and ransform data 4475546 row: 0.005 s
# time of get channel data 1735407 row: 0.326 s
# time of truncate and ransform data 1735407 row: 0.004 s
# time of get channel data 1183049 row: 0.282 s
# time of truncate and ransform data 1183049 row: 0.005 s
# time of get channel data 3676673 row: 0.645 s
# time of truncate and ransform data 3676673 row: 0.005 s
# time of get channel data 1446482 row: 0.148 s
# time of truncate and ransform data 1446482 row: 0.004 s
# time of get channel data 4693401 row: 0.587 s
# time of truncate and ransform data 4693401 row: 0.006 s
# time of get channel data 2716190 row: 0.286 s
# time of truncate and ransform data 2716190 row: 0.005 stime of get channel data 3284320 row: 0.346 stime of get channel data 329001 row: 0.426 s
#
# time of truncate and ransform data 329001 row: 0.005 stime of truncate and ransform data 3284320 row: 0.005 s
#
#
# time of get channel data 1481732 row: 0.260 s
# time of truncate and ransform data 1481732 row: 0.005 s
# time of get channel data 1562695 row: 0.243 s
# time of truncate and ransform data 1562695 row: 0.004 s
# time of get channel data 3233109 row: 0.352 s
# time of truncate and ransform data 3233109 row: 0.005 s
# time of get channel data 1744314 row: 0.281 s
# time of truncate and ransform data 1744314 row: 0.004 s
# time of get channel data 2233885 row: 0.312 stime of get channel data 5044233 row: 0.748 s
#
# time of get channel data 4661500 row: 0.510 stime of truncate and ransform data 5044233 row: 0.005 s
#
# time of truncate and ransform data 4661500 row: 0.005 stime of truncate and ransform data 2233885 row: 0.005 s
#
# time of get channel data 2726343 row: 0.224 stime of get channel data 2283563 row: 0.464 s
# time of truncate and ransform data 2726343 row: 0.005 s
#
# time of truncate and ransform data 2283563 row: 0.004 s
# time of get channel data 914722 row: 0.282 s
# time of truncate and ransform data 914722 row: 0.004 s
# time of get channel data 3214516 row: 0.139 s
# time of truncate and ransform data 3214516 row: 0.004 s
# time of get channel data 2485724 row: 0.359 s
# time of truncate and ransform data 2485724 row: 0.005 s
# time of get channel data 4519972 row: 0.884 s
# time of truncate and ransform data 4519972 row: 0.007 s
# time of get channel data 847275 row: 0.315 s
# time of truncate and ransform data 847275 row: 0.004 s
# time of get channel data 5179408 row: 0.632 s
# time of truncate and ransform data 5179408 row: 0.005 s
# time of get channel data 4009033 row: 0.959 s
# time of truncate and ransform data 4009033 row: 0.005 s
# time of get channel data 3110821 row: 0.442 s
# time of truncate and ransform data 3110821 row: 0.005 s
# time of get channel data 3502556 row: 0.422 stime of get channel data 4804553 row: 0.239 s
#
# time of truncate and ransform data 4804553 row: 0.005 s
# time of truncate and ransform data 3502556 row: 0.005 s
# time of get channel data 4114809 row: 0.796 s
# time of get channel data 2540914 row: 0.375 s
# time of truncate and ransform data 4114809 row: 0.004 s
# time of truncate and ransform data 2540914 row: 0.005 s
# time of get channel data 1693295 row: 0.250 s
# time of truncate and ransform data 1693295 row: 0.004 s
# time of get channel data 2058006 row: 0.316 s
# time of get channel data 3313555 row: 0.368 stime of truncate and ransform data 2058006 row: 0.004 s
#
# time of truncate and ransform data 3313555 row: 0.004 s
# time of get channel data 1898992 row: 0.421 s
# time of truncate and ransform data 1898992 row: 0.005 s
# time of get channel data 4491912 row: 0.663 s
# time of truncate and ransform data 4491912 row: 0.005 s
# time of get channel data 3046431 row: 0.256 s
# time of truncate and ransform data 3046431 row: 0.004 s
# time of get channel data 452531 row: 0.337 s
# time of truncate and ransform data 452531 row: 0.004 s
# time of get channel data 1524085 row: 0.336 s
# time of truncate and ransform data 1524085 row: 0.005 s
# time of get channel data 5082209 row: 0.649 s
# time of truncate and ransform data 5082209 row: 0.005 s
# time of get channel data 106258 row: 0.387 s
# time of truncate and ransform data 106258 row: 0.005 s
# time of get channel data 4444673 row: 0.455 s
# time of truncate and ransform data 4444673 row: 0.005 s
# time of get channel data 2087436 row: 0.297 s
# time of truncate and ransform data 2087436 row: 0.004 s
# time of get channel data 4633330 row: 0.723 s
# time of truncate and ransform data 4633330 row: 0.005 s
# time of get channel data 409225 row: 0.284 s
# time of truncate and ransform data 409225 row: 0.004 s
# time of get channel data 1867827 row: 0.128 s
# time of truncate and ransform data 1867827 row: 0.004 s
# time of get channel data 1385606 row: 0.421 s
# time of truncate and ransform data 1385606 row: 0.005 s
# time of get channel data 4945390 row: 0.659 s
# time of truncate and ransform data 4945390 row: 0.004 s
# time of get channel data 4357032 row: 0.720 s
# time of truncate and ransform data 4357032 row: 0.006 s
# time of get channel data 4232168 row: 0.539 s
# time of truncate and ransform data 4232168 row: 0.004 s
# time of get channel data 4861350 row: 0.838 s
# time of get channel data 1397516 row: 0.335 s
# time of truncate and ransform data 4861350 row: 0.005 stime of truncate and ransform data 1397516 row: 0.004 s
#
# time of get channel data 2571713 row: 0.327 s
# time of truncate and ransform data 2571713 row: 0.005 s
# time of get channel data 324463 row: 0.301 s
# time of truncate and ransform data 324463 row: 0.005 s
# time of get channel data 4949323 row: 0.939 s
# time of truncate and ransform data 4949323 row: 0.006 s
# time of get channel data 285733 row: 0.142 s
# time of truncate and ransform data 285733 row: 0.004 s
# time of get channel data 2834874 row: 0.583 stime of get channel data 3907337 row: 0.584 s
#
# time of truncate and ransform data 2834874 row: 0.004 stime of truncate and ransform data 3907337 row: 0.005 s
#
# time of get channel data 1975445 row: 0.426 s
# time of truncate and ransform data 1975445 row: 0.006 s
# time of get channel data 2864404 row: 0.504 s
# time of truncate and ransform data 2864404 row: 0.004 s
# time of get channel data 460656 row: 0.275 s
# time of truncate and ransform data 460656 row: 0.004 stime of get channel data 4537741 row: 0.914 s
#
# time of get channel data 3825728 row: 0.731 s
# time of truncate and ransform data 4537741 row: 0.005 s
# time of truncate and ransform data 3825728 row: 0.004 s
# time of get channel data 3334716 row: 0.352 s
# time of truncate and ransform data 3334716 row: 0.005 s
# time of get channel data 3420849 row: 0.343 s
# time of truncate and ransform data 3420849 row: 0.004 s
# time of get channel data 600584 row: 0.382 s
# time of truncate and ransform data 600584 row: 0.005 s
# time of get channel data 1839436 row: 0.503 s
# time of truncate and ransform data 1839436 row: 0.004 s
# time of get channel data 5190721 row: 0.276 s
# time of truncate and ransform data 5190721 row: 0.006 s
# time of get channel data 4536051 row: 0.683 s
# time of truncate and ransform data 4536051 row: 0.005 s
# time of get channel data 1647232 row: 0.500 s
# time of get channel data 3118029 row: 0.341 stime of truncate and ransform data 1647232 row: 0.004 s
#
# time of truncate and ransform data 3118029 row: 0.005 s
# time of get channel data 5057320 row: 0.678 s
# time of truncate and ransform data 5057320 row: 0.005 s
# time of get channel data 561678 row: 0.253 s
# time of truncate and ransform data 561678 row: 0.005 s
# time of get channel data 2981271 row: 0.305 s
# time of truncate and ransform data 2981271 row: 0.006 s
# time of get channel data 2086494 row: 0.455 s
# time of truncate and ransform data 2086494 row: 0.004 s
# time of get channel data 4964389 row: 0.500 s
# time of truncate and ransform data 4964389 row: 0.005 s
# time of get channel data 3974504 row: 0.621 s
# time of truncate and ransform data 3974504 row: 0.007 s
# time of get channel data 2290467 row: 0.332 s
# time of truncate and ransform data 2290467 row: 0.004 s
# time of get channel data 4689319 row: 0.688 s
# time of truncate and ransform data 4689319 row: 0.006 s
# time of get channel data 440365 row: 0.346 s
# time of truncate and ransform data 440365 row: 0.006 s
# time of get channel data 1296463 row: 0.239 s
# time of truncate and ransform data 1296463 row: 0.004 s
# time of get channel data 4530564 row: 1.025 s
# time of truncate and ransform data 4530564 row: 0.006 stime of get channel data 140193 row: 0.291 s
#
# time of truncate and ransform data 140193 row: 0.004 s
# time of get channel data 4592504 row: 0.696 s
# time of get channel data 430511 row: 0.219 s
# time of truncate and ransform data 4592504 row: 0.005 s
# time of truncate and ransform data 430511 row: 0.006 s
# time of get channel data 2594345 row: 0.294 s
# time of truncate and ransform data 2594345 row: 0.004 s
# time of get channel data 1769211 row: 0.305 s
# time of truncate and ransform data 1769211 row: 0.005 s
# time of get channel data 1514286 row: 0.286 s
# time of truncate and ransform data 1514286 row: 0.003 s
# time of get channel data 507859 row: 0.438 s
# time of truncate and ransform data 507859 row: 0.004 s
# time of get channel data 4370438 row: 1.138 s
# time of truncate and ransform data 4370438 row: 0.007 s
# time of get channel data 1933478 row: 0.321 s
# time of truncate and ransform data 1933478 row: 0.005 s
# time of get channel data 1387105 row: 0.173 s
# time of truncate and ransform data 1387105 row: 0.005 s
# time of get channel data 952108 row: 0.404 s
# time of truncate and ransform data 952108 row: 0.004 s
# time of get channel data 4556790 row: 0.567 s
# time of truncate and ransform data 4556790 row: 0.005 s
# time of get channel data 1742272 row: 0.331 s
# time of truncate and ransform data 1742272 row: 0.005 s
# time of get channel data 104424 row: 0.369 s
# time of truncate and ransform data 104424 row: 0.005 stime of get channel data 1152873 row: 0.239 s
#
# time of truncate and ransform data 1152873 row: 0.004 s
# time of get channel data 1372948 row: 0.196 s
# time of truncate and ransform data 1372948 row: 0.006 s
# time of get channel data 1610518 row: 0.318 s
# time of truncate and ransform data 1610518 row: 0.005 s
# time of get channel data 2569519 row: 0.328 s
# time of get channel data 823409 row: 0.236 stime of truncate and ransform data 2569519 row: 0.005 s
#
# time of truncate and ransform data 823409 row: 0.007 s
# time of get channel data 3418218 row: 0.284 s
# time of truncate and ransform data 3418218 row: 0.005 s
# time of get channel data 4508630 row: 0.570 s
# time of truncate and ransform data 4508630 row: 0.005 s
# time of get channel data 609044 row: 0.289 s
# time of truncate and ransform data 609044 row: 0.005 s
# time of get channel data 1280426 row: 0.384 s
# time of get channel data 1498932 row: 0.467 s
# time of truncate and ransform data 1280426 row: 0.004 s
# time of truncate and ransform data 1498932 row: 0.004 s
# time of get channel data 5045149 row: 0.714 s
# time of truncate and ransform data 5045149 row: 0.005 s
# time of get channel data 77565 row: 0.534 s
# time of truncate and ransform data 77565 row: 0.006 s
# time of get channel data 427064 row: 0.258 s
# time of truncate and ransform data 427064 row: 0.004 s
# time of get channel data 273929 row: 0.386 stime of get channel data 2337375 row: 0.308 s
#
# time of truncate and ransform data 273929 row: 0.006 s
# time of truncate and ransform data 2337375 row: 0.004 s
# time of get channel data 412758 row: 0.366 stime of get channel data 2925280 row: 0.128 stime of get channel data 1870973 row: 0.182 s
#
#
# time of truncate and ransform data 1870973 row: 0.006 stime of truncate and ransform data 412758 row: 0.006 s
# time of truncate and ransform data 2925280 row: 0.004 s
#
# time of get channel data 2899215 row: 0.631 s
# time of truncate and ransform data 2899215 row: 0.006 s
# time of get channel data 3307503 row: 0.439 s
# time of truncate and ransform data 3307503 row: 0.006 s
# time of get channel data 4642569 row: 0.550 s
# time of truncate and ransform data 4642569 row: 0.007 s
# time of get channel data 5240609 row: 0.635 s
# time of truncate and ransform data 5240609 row: 0.007 s
# time of get channel data 2782152 row: 0.339 s
# time of truncate and ransform data 2782152 row: 0.005 s
# time of get channel data 2902700 row: 0.307 s
# time of truncate and ransform data 2902700 row: 0.006 s
# time of get channel data 814129 row: 0.271 s
# time of truncate and ransform data 814129 row: 0.004 s
# time of get channel data 396377 row: 0.314 s
# time of truncate and ransform data 396377 row: 0.004 s
# time of get channel data 4122784 row: 0.814 s
# time of truncate and ransform data 4122784 row: 0.007 s
# time of get channel data 1878598 row: 0.560 s
# time of truncate and ransform data 1878598 row: 0.005 s
# time of get channel data 4556142 row: 1.171 s
# time of truncate and ransform data 4556142 row: 0.007 s
# time of get channel data 3225241 row: 0.634 s
# time of truncate and ransform data 3225241 row: 0.006 s
# time of get channel data 4651230 row: 0.567 s
# time of truncate and ransform data 4651230 row: 0.006 s
# time of get channel data 4415986 row: 1.043 s
# time of truncate and ransform data 4415986 row: 0.007 s
# time of get channel data 1656858 row: 0.383 s
# time of truncate and ransform data 1656858 row: 0.006 s
# time of get channel data 4970414 row: 0.685 s
# time of truncate and ransform data 4970414 row: 0.005 s
# time of get channel data 3807343 row: 0.806 s
# time of truncate and ransform data 3807343 row: 0.008 s
# time of get channel data 1671960 row: 0.379 s
# time of truncate and ransform data 1671960 row: 0.006 s
# time of get channel data 2128855 row: 0.426 s
# time of truncate and ransform data 2128855 row: 0.005 s
# time of get channel data 4733400 row: 0.689 s
# time of truncate and ransform data 4733400 row: 0.006 s
# time of get channel data 5170741 row: 0.501 s
# time of truncate and ransform data 5170741 row: 0.006 s
# time of get channel data 4505361 row: 0.700 s
# time of truncate and ransform data 4505361 row: 0.007 s
# time of get channel data 1937923 row: 0.569 s
# time of get channel data 1973334 row: 0.444 stime of truncate and ransform data 1937923 row: 0.005 stime of get channel data 1504609 row: 0.552 s
#
# time of truncate and ransform data 1973334 row: 0.006 s
#
# time of truncate and ransform data 1504609 row: 0.004 s
# time of get channel data 2594183 row: 0.252 s
# time of truncate and ransform data 2594183 row: 0.005 s
# time of get channel data 1087081 row: 0.276 s
# time of truncate and ransform data 1087081 row: 0.005 s
# time of get channel data 3497834 row: 0.300 s
# time of truncate and ransform data 3497834 row: 0.006 s
# time of get channel data 4886889 row: 0.422 s
# time of truncate and ransform data 4886889 row: 0.005 s
# time of get channel data 4311959 row: 0.733 s
# time of truncate and ransform data 4311959 row: 0.006 stime of get channel data 2199367 row: 0.458 s
#
# time of truncate and ransform data 2199367 row: 0.007 s
# time of get channel data 39746 row: 0.421 s
# time of truncate and ransform data 39746 row: 0.006 s
# time of get channel data 527475 row: 0.382 s
# time of truncate and ransform data 527475 row: 0.006 s
# time of get channel data 3462245 row: 0.353 s
# time of truncate and ransform data 3462245 row: 0.004 s
# time of get channel data 4133337 row: 1.051 s
# time of truncate and ransform data 4133337 row: 0.005 stime of get channel data 1799621 row: 0.342 s
#
# time of truncate and ransform data 1799621 row: 0.006 s
# time of get channel data 1317961 row: 0.363 s
# time of truncate and ransform data 1317961 row: 0.005 s
# time of get channel data 3917172 row: 0.886 s
# time of truncate and ransform data 3917172 row: 0.005 s
# time of get channel data 1337991 row: 0.262 s
# time of truncate and ransform data 1337991 row: 0.005 s
# time of get channel data 4324780 row: 0.560 s
# time of truncate and ransform data 4324780 row: 0.004 s
# time of get channel data 214535 row: 0.342 s
# time of truncate and ransform data 214535 row: 0.006 s
# time of get channel data 3832678 row: 0.647 s
# time of truncate and ransform data 3832678 row: 0.005 s
# time of get channel data 4051478 row: 0.556 s
# time of truncate and ransform data 4051478 row: 0.005 s
# time of get channel data 1718927 row: 0.147 s
# time of truncate and ransform data 1718927 row: 0.004 s
# time of get channel data 2348676 row: 0.346 s
# time of truncate and ransform data 2348676 row: 0.006 s
# time of get channel data 1812048 row: 0.364 s
# time of truncate and ransform data 1812048 row: 0.004 s
# time of get channel data 1712363 row: 0.474 s
# time of truncate and ransform data 1712363 row: 0.005 s
# time of get channel data 3356367 row: 0.243 s
# time of truncate and ransform data 3356367 row: 0.005 s
# time of get channel data 3633700 row: 0.516 stime of get channel data 4577622 row: 0.319 s
# time of truncate and ransform data 3633700 row: 0.005 s
#
# time of truncate and ransform data 4577622 row: 0.004 s
# time of get channel data 3777959 row: 0.691 s
# time of truncate and ransform data 3777959 row: 0.007 s
# time of get channel data 4058190 row: 0.797 stime of get channel data 2182148 row: 0.284 s
#
# time of truncate and ransform data 4058190 row: 0.007 stime of get channel data 2819466 row: 0.304 stime of truncate and ransform data 2182148 row: 0.004 s
#
#
# time of truncate and ransform data 2819466 row: 0.005 stime of get channel data 2858523 row: 0.317 s
#
# time of truncate and ransform data 2858523 row: 0.005 s
# time of get channel data 454873 row: 0.189 s
# time of truncate and ransform data 454873 row: 0.006 s
# time of get channel data 355515 row: 0.318 s
# time of truncate and ransform data 355515 row: 0.005 s
# time of get channel data 4726590 row: 0.732 stime of get channel data 1516281 row: 0.473 stime of get channel data 3986929 row: 0.736 s
# time of truncate and ransform data 3986929 row: 0.007 s
#
#
# time of truncate and ransform data 4726590 row: 0.004 s
# time of truncate and ransform data 1516281 row: 0.006 s
# time of get channel data 3447391 row: 0.253 s
# time of truncate and ransform data 3447391 row: 0.004 s
# time of get channel data 2095738 row: 0.295 s
# time of truncate and ransform data 2095738 row: 0.006 s
# time of get channel data 2914606 row: 0.282 stime of get channel data 4319681 row: 0.928 s
#
# time of truncate and ransform data 2914606 row: 0.004 stime of truncate and ransform data 4319681 row: 0.007 s
#
# time of get channel data 744646 row: 0.264 s
# time of truncate and ransform data 744646 row: 0.004 s
# time of get channel data 5082327 row: 0.300 s
# time of truncate and ransform data 5082327 row: 0.006 s
# time of get channel data 4139094 row: 0.918 s
# time of truncate and ransform data 4139094 row: 0.005 s
# time of get channel data 4931563 row: 0.714 s
# time of truncate and ransform data 4931563 row: 0.006 s
# time of get channel data 3527066 row: 0.340 s
# time of truncate and ransform data 3527066 row: 0.006 s
# time of get channel data 93657 row: 0.239 s
# time of truncate and ransform data 93657 row: 0.004 s
# time of get channel data 2063320 row: 0.629 s
# time of truncate and ransform data 2063320 row: 0.004 s
# time of get channel data 2148540 row: 0.326 s
# time of truncate and ransform data 2148540 row: 0.004 s
# time of get channel data 4047529 row: 0.767 s
# time of truncate and ransform data 4047529 row: 0.006 s
# time of get channel data 3401023 row: 0.316 s
# time of truncate and ransform data 3401023 row: 0.004 s
# time of get channel data 2203974 row: 0.505 s
# time of truncate and ransform data 2203974 row: 0.006 s
# time of get channel data 3641212 row: 0.747 s
# time of truncate and ransform data 3641212 row: 0.007 s
# time of get channel data 2041022 row: 0.365 s
# time of truncate and ransform data 2041022 row: 0.004 s
# time of get channel data 4979679 row: 0.636 s
# time of truncate and ransform data 4979679 row: 0.007 s
# time of get channel data 3080654 row: 0.397 s
# time of truncate and ransform data 3080654 row: 0.006 s
# time of get channel data 3138957 row: 0.445 s
# time of truncate and ransform data 3138957 row: 0.005 s
# time of get channel data 3989979 row: 0.490 s
# time of truncate and ransform data 3989979 row: 0.007 s
# time of get channel data 2956506 row: 0.315 s
# time of truncate and ransform data 2956506 row: 0.005 s
# time of get channel data 1631094 row: 0.332 s
# time of truncate and ransform data 1631094 row: 0.005 s
# time of get channel data 5235627 row: 0.641 s
# time of get channel data 1444210 row: 0.271 s
# time of truncate and ransform data 5235627 row: 0.006 s
# time of truncate and ransform data 1444210 row: 0.004 s
# time of get channel data 3232665 row: 0.143 s
# time of truncate and ransform data 3232665 row: 0.004 s
# time of get channel data 122309 row: 0.281 s
# time of truncate and ransform data 122309 row: 0.004 s
# time of get channel data 573877 row: 0.325 s
# time of truncate and ransform data 573877 row: 0.004 s
# time of get channel data 3849973 row: 0.872 s
# time of get channel data 4511148 row: 0.635 s
# time of truncate and ransform data 3849973 row: 0.006 stime of truncate and ransform data 4511148 row: 0.008 s
#
# time of get channel data 4281052 row: 0.838 s
# time of truncate and ransform data 4281052 row: 0.006 s
# time of get channel data 815206 row: 0.464 s
# time of truncate and ransform data 815206 row: 0.006 s
# time of get channel data 1864407 row: 0.273 s
# time of truncate and ransform data 1864407 row: 0.005 stime of get channel data 1513959 row: 0.153 s
#
# time of truncate and ransform data 1513959 row: 0.005 stime of get channel data 813797 row: 0.334 s
#
# time of truncate and ransform data 813797 row: 0.006 s
# time of get channel data 1431080 row: 0.364 s
# time of truncate and ransform data 1431080 row: 0.006 s
# time of get channel data 759507 row: 0.495 s
# time of truncate and ransform data 759507 row: 0.008 s
# time of get channel data 4101817 row: 0.640 s
# time of truncate and ransform data 4101817 row: 0.006 s
# time of get channel data 3172335 row: 0.377 s
# time of truncate and ransform data 3172335 row: 0.006 s
# time of get channel data 5113340 row: 1.158 stime of get channel data 2028940 row: 0.238 s
# time of truncate and ransform data 2028940 row: 0.004 s
#
# time of truncate and ransform data 5113340 row: 0.009 s
# time of get channel data 3042378 row: 0.363 s
# time of truncate and ransform data 3042378 row: 0.006 s
# time of get channel data 2459861 row: 0.382 s
# time of get channel data 3459675 row: 0.446 s
# time of truncate and ransform data 2459861 row: 0.005 stime of truncate and ransform data 3459675 row: 0.004 s
#
# time of get channel data 4029232 row: 0.488 s
# time of truncate and ransform data 4029232 row: 0.005 s
# time of get channel data 185335 row: 0.344 s
# time of truncate and ransform data 185335 row: 0.006 s
# time of get channel data 1246061 row: 0.256 s
# time of truncate and ransform data 1246061 row: 0.004 s
# time of get channel data 2426706 row: 0.139 s
# time of truncate and ransform data 2426706 row: 0.004 s
# time of get channel data 124559 row: 0.351 s
# time of truncate and ransform data 124559 row: 0.006 s
# time of get channel data 2908695 row: 0.501 s
# time of truncate and ransform data 2908695 row: 0.006 s
# time of get channel data 4521980 row: 0.758 s
# time of truncate and ransform data 4521980 row: 0.007 s
# time of get channel data 2397811 row: 0.403 s
# time of truncate and ransform data 2397811 row: 0.004 s
# time of get channel data 2376504 row: 0.433 s
# time of truncate and ransform data 2376504 row: 0.006 s
# time of get channel data 2107586 row: 0.327 s
# time of truncate and ransform data 2107586 row: 0.007 s
# time of get channel data 5029690 row: 0.603 s
# time of truncate and ransform data 5029690 row: 0.005 s
# time of get channel data 2117464 row: 0.440 s
# time of truncate and ransform data 2117464 row: 0.004 s
# time of get channel data 4249703 row: 0.770 s
# time of truncate and ransform data 4249703 row: 0.006 s
# time of get channel data 2739698 row: 0.386 s
# time of truncate and ransform data 2739698 row: 0.005 s
# time of get channel data 1426566 row: 0.294 s
# time of truncate and ransform data 1426566 row: 0.006 s
# time of get channel data 963639 row: 0.292 s
# time of truncate and ransform data 963639 row: 0.005 s
# time of get channel data 3517473 row: 0.510 s
# time of truncate and ransform data 3517473 row: 0.006 s
# time of get channel data 2462426 row: 0.648 s
# time of truncate and ransform data 2462426 row: 0.006 s
# time of get channel data 4995674 row: 0.931 s
# time of truncate and ransform data 4995674 row: 0.005 stime of get channel data 1902174 row: 0.345 s
#
# time of truncate and ransform data 1902174 row: 0.006 s
# time of get channel data 897226 row: 0.329 s
# time of truncate and ransform data 897226 row: 0.005 s
# time of get channel data 3631114 row: 0.952 s
# time of truncate and ransform data 3631114 row: 0.007 s
# time of get channel data 463487 row: 0.294 s
# time of truncate and ransform data 463487 row: 0.004 s
# time of get channel data 720113 row: 0.390 s
# time of truncate and ransform data 720113 row: 0.006 s
# time of get channel data 2090895 row: 0.275 s
# time of truncate and ransform data 2090895 row: 0.004 stime of get channel data 989182 row: 0.406 s
#
# time of truncate and ransform data 989182 row: 0.004 s
# time of get channel data 4566292 row: 0.733 s
# time of truncate and ransform data 4566292 row: 0.007 s
# time of get channel data 4445165 row: 0.326 s
# time of truncate and ransform data 4445165 row: 0.007 s
# time of get channel data 210091 row: 0.420 s
# time of truncate and ransform data 210091 row: 0.004 s
# time of get channel data 3792843 row: 0.725 s
# time of get channel data 4205972 row: 0.605 stime of truncate and ransform data 3792843 row: 0.007 s
#
# time of truncate and ransform data 4205972 row: 0.005 s
# time of get channel data 2335191 row: 0.697 s
# time of truncate and ransform data 2335191 row: 0.005 s
# time of get channel data 5042587 row: 0.575 s
# time of get channel data 1246021 row: 0.155 s
# time of truncate and ransform data 5042587 row: 0.005 s
# time of truncate and ransform data 1246021 row: 0.004 s
# time of get channel data 3991152 row: 0.450 s
# time of truncate and ransform data 3991152 row: 0.005 s
# time of get channel data 4669483 row: 0.654 stime of get channel data 3018489 row: 0.140 s
#
# time of get channel data 1892155 row: 0.315 s
# time of truncate and ransform data 4669483 row: 0.007 s
# time of truncate and ransform data 3018489 row: 0.004 stime of truncate and ransform data 1892155 row: 0.006 s
#
# time of get channel data 1217331 row: 0.298 s
# time of truncate and ransform data 1217331 row: 0.005 s
# time of get channel data 4498519 row: 0.642 s
# time of truncate and ransform data 4498519 row: 0.005 s
# time of get channel data 4139332 row: 0.522 stime of get channel data 5045066 row: 0.253 s
#
# time of truncate and ransform data 4139332 row: 0.004 s
# time of truncate and ransform data 5045066 row: 0.005 s
# time of get channel data 1434490 row: 0.308 s
# time of truncate and ransform data 1434490 row: 0.006 s
# time of get channel data 4620318 row: 0.761 s
# time of truncate and ransform data 4620318 row: 0.006 s
# time of get channel data 222475 row: 0.271 s
# time of truncate and ransform data 222475 row: 0.004 s
# time of get channel data 2903052 row: 0.139 s
# time of truncate and ransform data 2903052 row: 0.004 s
# time of get channel data 1324454 row: 0.428 s
# time of truncate and ransform data 1324454 row: 0.005 s
# time of get channel data 4117409 row: 0.714 s
# time of truncate and ransform data 4117409 row: 0.006 s
# time of get channel data 4807593 row: 0.332 s
# time of truncate and ransform data 4807593 row: 0.004 s
# time of get channel data 4188364 row: 0.689 s
# time of truncate and ransform data 4188364 row: 0.007 s
# time of get channel data 1366017 row: 0.196 s
# time of truncate and ransform data 1366017 row: 0.003 s
# time of get channel data 223012 row: 0.493 s
# time of truncate and ransform data 223012 row: 0.006 s
# time of get channel data 2692271 row: 0.356 s
# time of truncate and ransform data 2692271 row: 0.006 s
# time of get channel data 3545893 row: 0.501 s
# time of truncate and ransform data 3545893 row: 0.004 s
# time of get channel data 2595674 row: 0.310 s
# time of truncate and ransform data 2595674 row: 0.006 s
# time of get channel data 3445869 row: 0.291 s
# time of truncate and ransform data 3445869 row: 0.004 stime of get channel data 4632697 row: 0.608 s
#
# time of truncate and ransform data 4632697 row: 0.006 s
# time of get channel data 3133546 row: 0.139 s
# time of truncate and ransform data 3133546 row: 0.004 s
# time of get channel data 4815392 row: 0.569 s
# time of truncate and ransform data 4815392 row: 0.004 s
# time of get channel data 1924218 row: 0.402 stime of get channel data 3818683 row: 0.691 s
#
# time of truncate and ransform data 1924218 row: 0.006 s
# time of truncate and ransform data 3818683 row: 0.007 s
# time of get channel data 2716104 row: 0.156 s
# time of truncate and ransform data 2716104 row: 0.005 s
# time of get channel data 5143584 row: 0.330 s
# time of truncate and ransform data 5143584 row: 0.007 s
# time of get channel data 365795 row: 0.159 s
# time of truncate and ransform data 365795 row: 0.004 s
# time of get channel data 2007225 row: 0.385 s
# time of truncate and ransform data 2007225 row: 0.006 s
# time of get channel data 3551337 row: 0.717 stime of get channel data 5074197 row: 0.577 s
#
# time of truncate and ransform data 3551337 row: 0.005 s
# time of truncate and ransform data 5074197 row: 0.006 s
# time of get channel data 3743736 row: 0.805 s
# time of truncate and ransform data 3743736 row: 0.007 s
# time of get channel data 1247477 row: 0.659 s
# time of truncate and ransform data 1247477 row: 0.006 s
# time of get channel data 1646913 row: 0.384 s
# time of truncate and ransform data 1646913 row: 0.006 s
# time of get channel data 2816078 row: 0.380 s
# time of truncate and ransform data 2816078 row: 0.004 s
# time of get channel data 2008934 row: 0.331 s
# time of truncate and ransform data 2008934 row: 0.006 s
# time of get channel data 5219966 row: 0.839 s
# time of truncate and ransform data 5219966 row: 0.006 s
# time of get channel data 1789251 row: 0.380 s
# time of truncate and ransform data 1789251 row: 0.006 s
# time of get channel data 3678082 row: 0.549 s
# time of truncate and ransform data 3678082 row: 0.005 s
# time of get channel data 1016734 row: 0.408 s
# time of truncate and ransform data 1016734 row: 0.006 s
# time of get channel data 142012 row: 0.269 s
# time of truncate and ransform data 142012 row: 0.005 s
# time of get channel data 3372988 row: 0.312 s
# time of truncate and ransform data 3372988 row: 0.006 s
# time of get channel data 4076030 row: 0.447 s
# time of truncate and ransform data 4076030 row: 0.004 s
# time of get channel data 211014 row: 0.502 s
# time of truncate and ransform data 211014 row: 0.005 s
# time of get channel data 3338593 row: 0.472 s
# time of truncate and ransform data 3338593 row: 0.005 s
# time of get channel data 4724200 row: 0.704 s
# time of truncate and ransform data 4724200 row: 0.006 s
# time of get channel data 3939596 row: 0.893 s
# time of truncate and ransform data 3939596 row: 0.006 s
# time of get channel data 457693 row: 0.411 stime of get channel data 3995747 row: 0.684 s
# time of truncate and ransform data 3995747 row: 0.006 s
#
# time of truncate and ransform data 457693 row: 0.005 s
# time of get channel data 4941091 row: 0.314 s
# time of truncate and ransform data 4941091 row: 0.006 stime of get channel data 371941 row: 0.550 s
#
# time of truncate and ransform data 371941 row: 0.006 s
# time of get channel data 2131652 row: 0.368 s
# time of truncate and ransform data 2131652 row: 0.005 stime of get channel data 113278 row: 0.371 s
#
# time of truncate and ransform data 113278 row: 0.007 s
# ...
# time of truncate and ransform data 41978 row: 0.005 s
# time of get channel data 6474 row: 0.296 s
# time of truncate and ransform data 6474 row: 0.004 s
# time of get channel data 4121783 row: 0.639 s
# time of truncate and ransform data 4121783 row: 0.005 s
# time of get channel data 210753 row: 0.140 s
# time of truncate and ransform data 210753 row: 0.004 s
# time of get channel data 4317112 row: 0.944 s
# time of truncate and ransform data 4317112 row: 0.009 s
# time of get channel data 987255 row: 0.336 s
# time of truncate and ransform data 987255 row: 0.006 s
# time of get channel data 2144683 row: 0.390 s
# time of truncate and ransform data 2144683 row: 0.005 s
# time of get channel data 1955144 row: 0.347 s
# time of truncate and ransform data 1955144 row: 0.010 s
# time of get channel data 153247 row: 0.322 s
# time of truncate and ransform data 153247 row: 0.005 s
# time of get channel data 3019440 row: 0.181 s
# time of truncate and ransform data 3019440 row: 0.005 s
# time of get channel data 173923 row: 0.419 s
# time of truncate and ransform data 173923 row: 0.004 s
# time of get channel data 4918161 row: 0.180 s
# time of truncate and ransform data 4918161 row: 0.004 s
# time of get channel data 3402318 row: 0.414 s
# time of truncate and ransform data 3402318 row: 0.006 s
# time of get channel data 4236042 row: 0.770 s
# time of truncate and ransform data 4236042 row: 0.007 s
# time of get channel data 1277310 row: 0.416 s
# time of truncate and ransform data 1277310 row: 0.004 s
# time of get channel data 3912440 row: 0.362 s
# time of truncate and ransform data 3912440 row: 0.007 s
# time of get channel data 683578 row: 0.305 s
# time of truncate and ransform data 683578 row: 0.005 s
# time of get channel data 4093823 row: 0.588 s
# time of truncate and ransform data 4093823 row: 0.006 s
# time of get channel data 345756 row: 0.550 s
# time of truncate and ransform data 345756 row: 0.006 s
# time of get channel data 5252756 row: 0.664 s
# time of truncate and ransform data 5252756 row: 0.009 s
# time of get channel data 4371686 row: 0.913 s
# time of truncate and ransform data 4371686 row: 0.005 s
# time of get channel data 2628003 row: 0.672 s
# time of truncate and ransform data 2628003 row: 0.006 s
# time of get channel data 2474601 row: 0.296 s
# time of truncate and ransform data 2474601 row: 0.004 s
# time of get channel data 1006001 row: 0.334 s
# time of truncate and ransform data 1006001 row: 0.006 stime of get channel data 1833372 row: 0.188 s
#
# time of truncate and ransform data 1833372 row: 0.005 s
# time of get channel data 2324069 row: 0.278 s
# time of truncate and ransform data 2324069 row: 0.004 s
# time of get channel data 322284 row: 0.145 s
# time of truncate and ransform data 322284 row: 0.004 s
# time of get channel data 4597138 row: 0.580 s
# time of truncate and ransform data 4597138 row: 0.005 s
# time of get channel data 3857308 row: 0.680 s
# time of truncate and ransform data 3857308 row: 0.006 s
# time of get channel data 5065300 row: 0.741 s
# time of truncate and ransform data 5065300 row: 0.005 s
# time of get channel data 4290837 row: 0.790 s
# time of truncate and ransform data 4290837 row: 0.007 s
# time of get channel data 2033353 row: 0.288 s
# time of truncate and ransform data 2033353 row: 0.004 s
# time of get channel data 5031869 row: 0.813 s
# time of truncate and ransform data 5031869 row: 0.007 s
# time of get channel data 1539635 row: 0.122 s
# time of truncate and ransform data 1539635 row: 0.004 s
# time of get channel data 4125208 row: 0.364 s
# time of truncate and ransform data 4125208 row: 0.006 s
# time of get channel data 3320845 row: 0.504 stime of get channel data 3921056 row: 0.755 s
#
# time of truncate and ransform data 3320845 row: 0.007 stime of truncate and ransform data 3921056 row: 0.009 s
#
# time of get channel data 5108619 row: 0.333 s
# time of truncate and ransform data 5108619 row: 0.007 s
# time of get channel data 1998730 row: 0.256 s
# time of truncate and ransform data 1998730 row: 0.004 s
# time of get channel data 2366702 row: 0.227 s
# time of truncate and ransform data 2366702 row: 0.004 s
# time of get channel data 3474188 row: 0.426 s
# time of truncate and ransform data 3474188 row: 0.006 s
# time of get channel data 2616194 row: 0.543 s
# time of truncate and ransform data 2616194 row: 0.006 s
# time of get channel data 1155025 row: 0.415 s
# time of truncate and ransform data 1155025 row: 0.005 s
# time of get channel data 3839788 row: 0.603 s
# time of truncate and ransform data 3839788 row: 0.004 s
# time of get channel data 2314827 row: 0.128 s
# time of truncate and ransform data 2314827 row: 0.005 s
# time of get channel data 4399634 row: 0.763 s
# time of truncate and ransform data 4399634 row: 0.007 s
# time of get channel data 3365178 row: 0.158 s
# time of truncate and ransform data 3365178 row: 0.004 s
# time of get channel data 316513 row: 0.378 s
# time of truncate and ransform data 316513 row: 0.005 s
# time of get channel data 5252330 row: 0.245 s
# time of truncate and ransform data 5252330 row: 0.005 s
# time of get channel data 4272462 row: 0.795 s
# time of truncate and ransform data 4272462 row: 0.006 s
# time of get channel data 1787514 row: 0.204 s
# time of truncate and ransform data 1787514 row: 0.006 s
# time of get channel data 3280017 row: 0.356 s
# time of truncate and ransform data 3280017 row: 0.004 s
# time of get channel data 4861496 row: 0.221 s
# time of truncate and ransform data 4861496 row: 0.005 s
# time of get channel data 4151755 row: 0.649 s
# time of truncate and ransform data 4151755 row: 0.006 s
# time of get channel data 448271 row: 0.332 s
# time of truncate and ransform data 448271 row: 0.006 s
# time of get channel data 1960445 row: 0.143 s
# time of truncate and ransform data 1960445 row: 0.004 s
# time of get channel data 1317186 row: 0.173 s
# time of truncate and ransform data 1317186 row: 0.005 s
# time of get channel data 1839045 row: 0.186 s
# time of truncate and ransform data 1839045 row: 0.006 s
# time of get channel data 462588 row: 0.281 s
# time of truncate and ransform data 462588 row: 0.004 s
# time of get channel data 1428434 row: 0.254 s
# time of truncate and ransform data 1428434 row: 0.007 s
# time of get channel data 3783113 row: 0.763 s
# time of truncate and ransform data 3783113 row: 0.005 s
# time of get channel data 3979674 row: 0.484 s
# time of truncate and ransform data 3979674 row: 0.005 s
# time of get channel data 4933309 row: 0.637 s
# time of truncate and ransform data 4933309 row: 0.009 s
# time of get channel data 3570066 row: 0.886 s
# time of truncate and ransform data 3570066 row: 0.007 s
# time of get channel data 3319396 row: 0.342 s
# time of truncate and ransform data 3319396 row: 0.006 s
# time of get channel data 745763 row: 0.305 s
# time of truncate and ransform data 745763 row: 0.005 s
# time of get channel data 497856 row: 0.336 s
# time of truncate and ransform data 497856 row: 0.005 s
# time of get channel data 4380679 row: 0.703 s
# time of truncate and ransform data 4380679 row: 0.007 s
# time of get channel data 2405281 row: 0.503 s
# time of truncate and ransform data 2405281 row: 0.006 s
# time of get channel data 3648529 row: 0.329 s
# time of truncate and ransform data 3648529 row: 0.006 s
# time of get channel data 4375608 row: 0.671 s
# time of truncate and ransform data 4375608 row: 0.007 s
# time of get channel data 5046103 row: 0.657 s
# time of truncate and ransform data 5046103 row: 0.007 s
# time of get channel data 501749 row: 0.332 s
# time of truncate and ransform data 501749 row: 0.004 s
# time of get channel data 4064068 row: 0.624 s
# time of truncate and ransform data 4064068 row: 0.006 s
# time of get channel data 659632 row: 0.388 s
# time of truncate and ransform data 659632 row: 0.006 s
# time of get channel data 3495437 row: 0.311 s
# time of truncate and ransform data 3495437 row: 0.006 s
# time of get channel data 133476 row: 0.413 s
# time of truncate and ransform data 133476 row: 0.005 s
# time of get channel data 2699526 row: 0.401 s
# time of truncate and ransform data 2699526 row: 0.006 s
# time of get channel data 314662 row: 0.431 s
# time of truncate and ransform data 314662 row: 0.006 s
# time of get channel data 2809765 row: 0.368 s
# time of truncate and ransform data 2809765 row: 0.006 s
# time of get channel data 3988152 row: 0.357 s
# time of truncate and ransform data 3988152 row: 0.003 s
# time of get channel data 969599 row: 0.400 s
# time of truncate and ransform data 969599 row: 0.006 s
# time of get channel data 5253292 row: 0.821 s
# time of truncate and ransform data 5253292 row: 0.007 s
# time of get channel data 1750221 row: 0.555 s
# time of truncate and ransform data 1750221 row: 0.005 s
# time of get channel data 555380 row: 0.318 s
# time of truncate and ransform data 555380 row: 0.005 s
# time of get channel data 1891313 row: 0.305 s
# time of truncate and ransform data 1891313 row: 0.004 s
# time of get channel data 4987530 row: 0.733 s
# time of truncate and ransform data 4987530 row: 0.007 s
# time of get channel data 1850066 row: 0.334 s
# time of truncate and ransform data 1850066 row: 0.006 s
# time of get channel data 4739074 row: 0.706 s
# time of truncate and ransform data 4739074 row: 0.006 s
# time of get channel data 2695071 row: 0.334 s
# time of truncate and ransform data 2695071 row: 0.007 s
# time of get channel data 4575050 row: 0.606 s
# time of truncate and ransform data 4575050 row: 0.006 s
# time of get channel data 2565666 row: 0.279 s
# time of truncate and ransform data 2565666 row: 0.004 s
# time of get channel data 3207236 row: 0.441 s
# time of truncate and ransform data 3207236 row: 0.005 s
# time of get channel data 175253 row: 0.323 s
# time of truncate and ransform data 175253 row: 0.005 s
# time of get channel data 4214391 row: 0.772 s
# time of truncate and ransform data 4214391 row: 0.007 s
# time of get channel data 421944 row: 0.454 s
# time of truncate and ransform data 421944 row: 0.006 s
# time of get channel data 1935316 row: 0.347 s
# time of truncate and ransform data 1935316 row: 0.005 s
# time of get channel data 101366 row: 0.396 s
# time of truncate and ransform data 101366 row: 0.005 s
# time of get channel data 4077323 row: 0.647 s
# time of truncate and ransform data 4077323 row: 0.006 s
# time of get channel data 971185 row: 0.505 s
# time of truncate and ransform data 971185 row: 0.006 s
# time of get channel data 1319239 row: 0.573 s
# time of truncate and ransform data 1319239 row: 0.006 s
# time of get channel data 4883791 row: 0.736 s
# time of truncate and ransform data 4883791 row: 0.007 s
# time of get channel data 416169 row: 0.383 s
# time of truncate and ransform data 416169 row: 0.007 s
# time of get channel data 513794 row: 0.348 s
# time of truncate and ransform data 513794 row: 0.005 s
# time of get channel data 233712 row: 0.422 s
# time of truncate and ransform data 233712 row: 0.005 s
# time of get channel data 737106 row: 0.159 s
# time of truncate and ransform data 737106 row: 0.004 s
# time of get channel data 175459 row: 0.135 s
# time of truncate and ransform data 175459 row: 0.005 s
# time of get channel data 2723435 row: 0.409 s
# time of truncate and ransform data 2723435 row: 0.004 s
# time of get channel data 3145151 row: 0.382 s
# time of truncate and ransform data 3145151 row: 0.004 s
# time of get channel data 1699510 row: 0.158 s
# time of truncate and ransform data 1699510 row: 0.004 s
# time of get channel data 1017949 row: 0.378 s
# time of truncate and ransform data 1017949 row: 0.004 s
# time of get channel data 4868730 row: 0.507 s
# time of truncate and ransform data 4868730 row: 0.004 s
# time of get channel data 294883 row: 0.279 s
# time of truncate and ransform data 294883 row: 0.004 s
# time of get channel data 4650009 row: 0.547 s
# time of truncate and ransform data 4650009 row: 0.005 s
# time of get channel data 4511949 row: 1.140 s
# time of truncate and ransform data 4511949 row: 0.007 s
# time of get channel data 4259109 row: 0.910 s
# time of truncate and ransform data 4259109 row: 0.006 s
# time of get channel data 3668861 row: 0.667 s
# time of truncate and ransform data 3668861 row: 0.006 s
# time of get channel data 1920514 row: 0.361 s
# time of truncate and ransform data 1920514 row: 0.005 s
# time of get channel data 2298574 row: 0.353 s
# time of truncate and ransform data 2298574 row: 0.007 s
# time of get channel data 1653792 row: 0.290 s
# time of truncate and ransform data 1653792 row: 0.004 s
# time of get channel data 1386594 row: 0.157 s
# time of truncate and ransform data 1386594 row: 0.004 s
# time of get channel data 42077 row: 0.162 s
# time of truncate and ransform data 42077 row: 0.005 s
# time of get channel data 832509 row: 0.399 s
# time of truncate and ransform data 832509 row: 0.006 s
# time of get channel data 280371 row: 0.377 s
# time of truncate and ransform data 280371 row: 0.006 s
# time of get channel data 5173419 row: 0.764 s
# time of truncate and ransform data 5173419 row: 0.007 s
# time of get channel data 2980576 row: 0.340 s
# time of truncate and ransform data 2980576 row: 0.006 s
# time of get channel data 4237839 row: 0.816 s
# time of truncate and ransform data 4237839 row: 0.007 s
# time of get channel data 4893764 row: 0.725 s
# time of truncate and ransform data 4893764 row: 0.007 s
# time of get channel data 1610734 row: 0.392 s
# time of truncate and ransform data 1610734 row: 0.006 s
# time of get channel data 2828340 row: 0.378 s
# time of truncate and ransform data 2828340 row: 0.005 s
# time of get channel data 5035341 row: 0.654 s
# time of truncate and ransform data 5035341 row: 0.006 s
# time of get channel data 2090316 row: 0.170 s
# time of truncate and ransform data 2090316 row: 0.005 s
# time of get channel data 14719 row: 0.311 s
# time of truncate and ransform data 14719 row: 0.005 s
# time of get channel data 344404 row: 0.880 s
# time of truncate and ransform data 344404 row: 0.006 s
# time of get channel data 1583212 row: 0.453 s
# time of truncate and ransform data 1583212 row: 0.006 s
# time of get channel data 3080187 row: 0.368 s
# time of truncate and ransform data 3080187 row: 0.006 s
# time of get channel data 1544740 row: 0.361 s
# time of truncate and ransform data 1544740 row: 0.005 s
# time of get channel data 1366998 row: 0.377 s
# time of truncate and ransform data 1366998 row: 0.005 s
# time of get channel data 3882034 row: 0.744 s
# time of truncate and ransform data 3882034 row: 0.006 s
# time of get channel data 894961 row: 0.453 s
# time of truncate and ransform data 894961 row: 0.006 s
# time of get channel data 324306 row: 0.272 s
# time of truncate and ransform data 324306 row: 0.004 s
# time of get channel data 610892 row: 0.333 s
# time of truncate and ransform data 610892 row: 0.004 s
# time of get channel data 135450 row: 0.161 s
# time of truncate and ransform data 135450 row: 0.004 s
# time of get channel data 2133019 row: 0.281 s
# time of truncate and ransform data 2133019 row: 0.005 s
# time of get channel data 4210223 row: 0.286 s
# time of truncate and ransform data 4210223 row: 0.005 s
# time of get channel data 1446975 row: 0.163 s
# time of truncate and ransform data 1446975 row: 0.004 s
# time of get channel data 3600527 row: 0.706 s
# time of truncate and ransform data 3600527 row: 0.006 s
# time of get channel data 1823391 row: 0.468 s
# time of truncate and ransform data 1823391 row: 0.006 s
# time of get channel data 1521530 row: 0.371 s
# time of truncate and ransform data 1521530 row: 0.005 s
# time of get channel data 354875 row: 0.245 s
# time of truncate and ransform data 354875 row: 0.005 s
# time of get channel data 4364104 row: 0.735 s
# time of truncate and ransform data 4364104 row: 0.005 s
# time of get channel data 4050977 row: 0.766 s
# time of truncate and ransform data 4050977 row: 0.005 s
# time of get channel data 4052603 row: 0.527 s
# time of truncate and ransform data 4052603 row: 0.005 s
# time of get channel data 4135198 row: 0.864 s
# time of truncate and ransform data 4135198 row: 0.007 s
# time of get channel data 4701937 row: 0.882 s
# time of truncate and ransform data 4701937 row: 0.006 s
# time of get channel data 5175607 row: 0.757 s
# time of truncate and ransform data 5175607 row: 0.006 s
# time of get channel data 3751476 row: 0.557 s
# time of truncate and ransform data 3751476 row: 0.005 s
# time of get channel data 2531297 row: 0.183 s
# time of truncate and ransform data 2531297 row: 0.005 s

# %%
x, y = batch
print(x.shape)
print(y.shape)
# Out:
# torch.Size([4, 3840, 1])
# torch.Size([4, 1])

# %%
print(epoch_df.shape)
# Out:
# (7568873, 18)

# %%
import time, numpy as np, torch

x0 = x[0].squeeze(-1).cpu().numpy()          # (3840,)  or (3840,1) → (3840,)
np.savez("test.npz", signal=x0)
print("saved:", "test.npz", x0.shape)


t0 = time.perf_counter()
with np.load("test.npz") as npz:
    sig = npz["signal"]
t1 = time.perf_counter()

print(f"load time: {(t1 - t0)*1e3:.2f} ms  |  shape: {sig.shape}")
# Out:
# saved: test.npz (3840,)
# load time: 1.66 ms  |  shape: (3840,)
